# %% [markdown]
# # FRAUD DETECTION in FINANCIAL TRANSACTION

# %% [markdown]
# 1) Build a machine learning model to identify fraudulent credit card
# transactions.
# 2) Preprocess and normalize the transaction data, handle class
# imbalance issues, and split the dataset into training and testing sets.
# 3) Train a classification algorithm, such as logistic regression or random
# forests, to classify transactions as fraudulent or genuine.
# Evaluate the model's performance using metrics like precision, recall,
# and F1-score, and consider techniques like oversampling or
# undersampling for improving results.

# %% [markdown]
# ### Datasets link: https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# warningss
import warnings
warnings.filterwarnings('ignore')

# split data
from sklearn.model_selection import train_test_split

# Linear Regression
from sklearn.linear_model import LinearRegression, LogisticRegression

# Polynomial features
from sklearn.preprocessing import PolynomialFeatures

# calculate accuracy
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, accuracy_score

# %%
df = pd.read_csv("creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
input1 = df.iloc[0, :30].values
input1
# Out:
# array([ 0.00000000e+00, -1.35980713e+00, -7.27811733e-02,  2.53634674e+00,
#         1.37815522e+00, -3.38320770e-01,  4.62387778e-01,  2.39598554e-01,
#         9.86979013e-02,  3.63786970e-01,  9.07941720e-02, -5.51599533e-01,
#        -6.17800856e-01, -9.91389847e-01, -3.11169354e-01,  1.46817697e+00,
#        -4.70400525e-01,  2.07971242e-01,  2.57905802e-02,  4.03992960e-01,
#         2.51412098e-01, -1.83067779e-02,  2.77837576e-01, -1.10473910e-01,
#         6.69280749e-02,  1.28539358e-01, -1.89114844e-01,  1.33558377e-01,
#        -2.10530535e-02,  1.49620000e+02])

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df["Class"].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# #### Number of legit transactions are: 284315 & illegal transactions are 492
#
# number of legit transactions >> number of illegal transactions

# %%
legit_df = df[df["Class"] == 0]
illegal_df = df[df["Class"] == 1]

# %%
legit_df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
illegal_df.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 541    406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623    472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920  4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108  6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329  7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 541  -2.537387  1.391657 -2.770089  ...  0.517232 -0.035049 -0.465211
# 623   0.325574 -0.067794 -0.270953  ...  0.661696  0.435477  1.375966
# 4920  0.562320 -0.399147 -0.238253  ... -0.294166 -0.932391  0.172726
# 6108 -3.496197 -0.248778 -0.247768  ...  0.573574  0.176968 -0.436207
# 6329  1.713445 -0.496358 -1.282858  ... -0.379068 -0.704181 -0.656805
#
#            V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
df.groupby("Class").mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
legit_rnd_df = legit_df.sample(1500)
legit_rnd_df.shape
# Out:
# (1500, 31)

# %%
new_df = pd.concat([legit_rnd_df, illegal_df])

# %%
new_df.groupby("Class").mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      95091.537333  0.000610  0.021992  0.021036 -0.024090 -0.003115
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0     -0.061349 -0.032286 -0.054544  0.000127  ... -0.027110 -0.002147
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.002954 -0.009940 -0.000609 -0.017689  0.004842 -0.003662 -0.006015
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       80.184547
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# ### Data splting, training, testing

# %%
x = new_df.iloc[:, :30]
x.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 276834  167323.0  1.885350 -0.980880 -0.610408 -0.640439 -1.122583 -0.928749
# 72394    54689.0  1.233451  0.234375  0.503933  0.627647 -0.456236 -0.975856
# 5501      5546.0 -1.992666  2.311678  0.564862  0.313650 -1.102261 -1.344042
# 154467  101674.0  2.263084 -1.169959 -0.211616 -1.167922 -1.593939 -1.003038
# 9472     14029.0 -0.403735  1.031691  1.907977  1.058041  0.146739  0.431055
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 276834 -0.628718 -0.061526  1.798119  ... -0.104189  0.210323  0.534713
# 72394   0.108309 -0.232167 -0.017967  ... -0.038142 -0.244437 -0.719356
# 5501   -0.295168  0.947482  0.484105  ... -0.139884 -0.119503 -0.408391
# 154467 -1.273893 -0.366126  0.050445  ... -0.448881 -0.254177  0.135498
# 9472    0.162244  0.042700  1.370768  ...  0.214003 -0.037754  0.564460
#
# ...

# %%
y = new_df.iloc[: , 30]
y.head()
# Out:
# 276834    0
# 72394     0
# 5501      0
# 154467    0
# 9472      0
# Name: Class, dtype: int64

# %%
x = x.values
y = y.values

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.1, random_state = 5)

# %%
reg = LogisticRegression()

# %%
reg.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = reg.predict(x_test)

# %%
reg.predict([input1])
# Out:
# array([0], dtype=int64)

# %%
accuracy_score(y_pred, y_test)
# Out:
# 0.975

# %% [markdown]
# ### So, accuracy of predicting score is 97.5%
